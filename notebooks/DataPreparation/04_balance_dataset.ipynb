# %% [markdown]
# # Balance Dataset
#
# This notebook is currently a documented placeholder for the dataset-balancing stage. Add code here after deciding the final sampling strategy, such as undersampling overrepresented classes, oversampling rare classes, or splitting by image while preserving class coverage.

# %% [markdown]
# ## Suggested Workflow
#
# 1. Load `../data/processed/01_merged_nih_vinbig_training_boxes.csv`.
# 2. Count annotations and unique images per `label_name`.
# 3. Decide whether balancing should happen by annotation row or by image.
# 4. Write a new balanced CSV under `../data/processed/` and keep the original merged CSV unchanged.
# 5. Recount labels after balancing to verify the result.
